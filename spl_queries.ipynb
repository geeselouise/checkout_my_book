# %%
from splapi import checkout_titles

# %%
pl = checkout_titles()

# %%
pl.load_subset(limit=1000, query='select * where checkoutyear=2019 and checkoutmonth < 13 limit 5000000')
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
#   usageclass checkouttype materialtype checkoutyear checkoutmonth checkouts  \
# 0    Digital    OverDrive        EBOOK         2019             1         1
# 1    Digital    OverDrive        EBOOK         2019             2         1
# 2    Digital    OverDrive        EBOOK         2019             2         2
# 3    Digital    OverDrive        EBOOK         2019             3         2
# 4   Physical      Horizon    VIDEODISC         2019             3         2
#
#                                     title         creator  \
# 0                 Dog Diaries #6: Sweetie      Kate Klimo
# 1                               Delicious     Lori Foster
# 2            A Journal of the Plague Year    Daniel Defoe
# 3                    The Cocoa Conspiracy  Andrea Penrose
# 4  India / Pilot Film and TV Productions.             NaN
#
# ...

# %%
pl.results_df.shape
# Out:
# (2589001, 11)

# %%
pl.save_subset('C:/Users/louisa/Documents/GitHub/checkout_my_book/checkouts2019.csv')

# %%
pl.load_subset(limit=1000, query='select * where checkoutyear=2020 and checkoutmonth < 13 limit 5000000')
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
#   usageclass checkouttype materialtype checkoutyear checkoutmonth checkouts  \
# 0   Physical      Horizon         BOOK         2020             8         1
# 1    Digital    OverDrive        EBOOK         2020             8         1
# 2    Digital    OverDrive        EBOOK         2020             8         5
# 3    Digital    OverDrive        EBOOK         2020             8         1
# 4    Digital    OverDrive        EBOOK         2020             8         1
#
#                    title                creator  \
# 0  Harvest / Sam Inglis.            Inglis, Sam
# 1          The Race Beat           Gene Roberts
# 2       I Can Cook Vegan  Isa Chandra Moskowitz
# 3  Follow the Stars Home            Luanne Rice
# 4     Blood of Innocence              Tami Dane
#
#                                    subjects             publisher  \
# ...

# %%
pl.results_df.shape
# Out:
# (1721376, 11)

# %%
pl.save_subset('C:/Users/louisa/Documents/GitHub/checkout_my_book/checkouts2020.csv')

# %%
pl.load_subset(limit=1000, query='select * where checkoutyear=2021 and checkoutmonth < 10 limit 5000000')
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
#   usageclass checkouttype materialtype checkoutyear checkoutmonth checkouts  \
# 0    Digital    OverDrive        EBOOK         2021             1         4
# 1    Digital    OverDrive        EBOOK         2021             1         1
# 2    Digital    OverDrive        EBOOK         2021             1         1
# 3    Digital    OverDrive        EBOOK         2021             1         2
# 4    Digital    OverDrive    AUDIOBOOK         2021             1         2
#
#                                     title         creator  \
# 0                               Plainsong      Kent Haruf
# 1                    Second Life: A Novel    S. J. Watson
# 2  Ethan in Gold: Johnnies Series, Book 3        Amy Lane
# 3                 Beauchamp Hall: A Novel  Danielle Steel
# 4                    Shardik (Unabridged)   Richard Adams
#
# ...

# %%
pl.save_subset('C:/Users/louisa/Documents/GitHub/checkout_my_book/checkouts2021.csv')

# %%
base = 'C:/Users/louisa/Documents/GitHub/checkout_my_book/'
filepaths = [base + 'checkouts2019.csv', base + 'checkouts2020.csv', base + 'checkouts2021.csv']
pl.update_dataset(filepaths)
# Out:
#    Unnamed: 0 usageclass checkouttype materialtype  checkoutyear  \
# 0           0    Digital    OverDrive        EBOOK          2019
# 1           1    Digital    OverDrive        EBOOK          2019
# 2           2    Digital    OverDrive        EBOOK          2019
# 3           3    Digital    OverDrive        EBOOK          2019
# 4           4   Physical      Horizon    VIDEODISC          2019
#
#    checkoutmonth  checkouts                                   title  \
# 0              1          1                 Dog Diaries #6: Sweetie
# 1              2          1                               Delicious
# 2              2          2            A Journal of the Plague Year
# 3              3          2                    The Cocoa Conspiracy
# 4              3          2  India / Pilot Film and TV Productions.
#
#           creator                                     subjects  \
# 0      Kate Klimo        Juvenile Fiction, Juvenile Literature
# ...

# %%
pl.save_subset('C:/Users/louisa/Documents/GitHub/checkout_my_book/checkouts19-21.csv', update=True)

# %%
pl.load_subset(limit=1000, query='select * where checkoutyear=2018 and checkoutmonth < 13 limit 5000000')
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
#   usageclass checkouttype materialtype checkoutyear checkoutmonth checkouts  \
# 0    Digital    OverDrive        EBOOK         2018             1        22
# 1    Digital       Hoopla   TELEVISION         2018             1         1
# 2   Physical      Horizon    SOUNDDISC         2018             1         1
# 3    Digital    OverDrive        EBOOK         2018             1         2
# 4    Digital    OverDrive        EBOOK         2018             1         1
#
#                                             title                    creator  \
# 0                              Enemy of the State                Vince Flynn
# 1  Newspaper Mom / Cucumber in Rio / Donut Raffle                        NaN
# 2                           Mono / the Mavericks.  Mavericks (Musical group)
# 3                                   Anna Karenina                Leo Tolstoy
# ...

# %%
pl.save_subset('C:/Users/louisa/Documents/GitHub/checkout_my_book/checkouts2018.csv')

# %%
pl.load_subset(limit=1000, query='select * where checkoutyear=2017 and checkoutmonth < 13 limit 5000000')
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
#   usageclass checkouttype materialtype checkoutyear checkoutmonth checkouts  \
# 0    Digital    OverDrive        EBOOK         2017             8         3
# 1    Digital    OverDrive        EBOOK         2017             8        13
# 2   Physical      Horizon         BOOK         2017             8         1
# 3    Digital       Hoopla        MOVIE         2017             8         1
# 4   Physical      Horizon         BOOK         2017             8        23
#
#                                                title  \
# 0        Culdesac: War with No Name Series, Book 1.5
# 1                                       Among Others
# 2  The divine comedy / Dante Alighieri ; translat...
# 3                                  Against The Grain
# 4  Biscuit feeds the pets / story by Alyssa Satin...
#
#                           creator  \
# 0                   Robert Repino
# ...

# %%
pl.save_subset('C:/Users/louisa/Documents/GitHub/checkout_my_book/checkouts2017.csv')

# %%
pl.load_subset(limit=1000, query='select * where checkoutyear=2016 and checkoutmonth < 13 limit 5000000')
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
#   usageclass checkouttype materialtype checkoutyear checkoutmonth checkouts  \
# 0    Digital    OverDrive        EBOOK         2016            10         1
# 1   Physical      Horizon    VIDEODISC         2016            10         7
# 2    Digital    OverDrive        EBOOK         2016            10         1
# 3   Physical      Horizon         BOOK         2016            10         1
# 4   Physical      Horizon    SOUNDDISC         2016            10         3
#
#                                                title          creator  \
# 0  Slim by Design: Mindless Eating Solutions for ...    Brian Wansink
# 1  Trollflöjten [videorecording] = The magic flut...              NaN
# 2                                 Great Expectations  Charles Dickens
# 3                    A dangerous friend / Ward Just.    Just, Ward S.
# ...

# %%
pl.save_subset('C:/Users/louisa/Documents/GitHub/checkout_my_book/checkouts2016.csv')

# %%
pl.load_subset(limit=1000, query='select * where checkoutyear=2015 and checkoutmonth < 13 limit 5000000')
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
#   usageclass checkouttype materialtype checkoutyear checkoutmonth checkouts  \
# 0   Physical      Horizon         BOOK         2015             1         1
# 1   Physical      Horizon        MIXED         2015             1         1
# 2    Digital      Freegal         SONG         2015             1         1
# 3    Digital       Hoopla        MUSIC         2015             1         8
# 4    Digital      Freegal         SONG         2015             1         1
#
#                                                title  \
# 0                                      Paradise walk
# 1  ILLM Father of the atom Democritus and the nat...
# 2                                               Weak
# 3                                       Sadnecessary
# 4                                  The Last Farewell
#
#                                     subjects     creator         publisher  \
# ...

# %%
pl.save_subset('C:/Users/louisa/Documents/GitHub/checkout_my_book/checkouts2015.csv')

# %%
base = 'C:/Users/louisa/Documents/GitHub/checkout_my_book/'
filepaths = [base + 'checkouts2018.csv', base + 'checkouts2017.csv', base + 'checkouts2016.csv', base + 'checkouts2015.csv']
pl.update_dataset(filepaths)
# Out:
#    Unnamed: 0 usageclass checkouttype materialtype  checkoutyear  \
# 0           0    Digital    OverDrive        EBOOK          2018
# 1           1    Digital       Hoopla   TELEVISION          2018
# 2           2   Physical      Horizon    SOUNDDISC          2018
# 3           3    Digital    OverDrive        EBOOK          2018
# 4           4    Digital    OverDrive        EBOOK          2018
#
#    checkoutmonth  checkouts                                           title  \
# 0              1         22                              Enemy of the State
# 1              1          1  Newspaper Mom / Cucumber in Rio / Donut Raffle
# 2              1          1                           Mono / the Mavericks.
# 3              1          2                                   Anna Karenina
# 4              1          1                     Dragon: Vlad Series, Book 8
#
#                      creator                                 subjects  \
# ...

# %%
pl.save_subset('C:/Users/louisa/Documents/GitHub/checkout_my_book/checkouts15-18.csv', update=True)

# %%
filepaths = [base + 'checkouts15-18.csv', base + 'checkouts19-21.csv']
pl.update_dataset(filepaths)
# Out:
#    Unnamed: 0  Unnamed: 0.1 usageclass checkouttype materialtype  \
# 0           0             0    Digital    OverDrive        EBOOK
# 1           1             1    Digital       Hoopla   TELEVISION
# 2           2             2   Physical      Horizon    SOUNDDISC
# 3           3             3    Digital    OverDrive        EBOOK
# 4           4             4    Digital    OverDrive        EBOOK
#
#    checkoutyear  checkoutmonth  checkouts  \
# 0          2018              1         22
# 1          2018              1          1
# 2          2018              1          1
# 3          2018              1          2
# 4          2018              1          1
#
#                                             title                    creator  \
# 0                              Enemy of the State                Vince Flynn
# 1  Newspaper Mom / Cucumber in Rio / Donut Raffle                        NaN
# 2                           Mono / the Mavericks.  Mavericks (Musical group)
# ...

# %%
pl.save_subset('C:/Users/louisa/Documents/GitHub/checkout_my_book/checkouts15-21.csv', update=True)
